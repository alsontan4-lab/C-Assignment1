# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## Author
# Alson

# %% [markdown]
# **Objectives:**
#
#
# *   List the popular languages that Data Science Use
# *   List the popular libraries that Data Science Use
# * List the tools that the common for Data Science Use

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Matplotlib
# 2. Numpy
# 3. Scikit-learn
# 4. Seaborn
# 5. Pandas

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook|
# |R Studio|
# |Apache Zeppelin|

# %% [markdown]
# ###Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60
min = 200
hours = min / 60
print(hours)
# Out:
# 3.3333333333333335
